# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns',None)

# %%
df=pd.read_csv('gurgaon_properties_cleaned_v2.csv')

# %%
df=df.drop_duplicates()

# %%
df.head()
# Out:
#   property_type                                   society      sector  price  \
# 0          flat                               vatika city   sector 49   1.69
# 1          flat                  pareena coban residences  sector 99a   1.10
# 2         house                            unitech espace   sector 50   7.50
# 3          flat  central park resort belgravia residences   sector 48   6.25
# 4          flat                            dlf the ultima   sector 81   2.35
#
#    price_per_sqft    area                                       areaWithType  \
# 0          8622.0  1960.0                   Carpet area: 1960 (182.09 sq.m.)
# 1          7096.0  1550.0  Super Built up area 1550(144 sq.m.)Carpet area...
# 2         34722.0  2160.0  Plot area 240(200.67 sq.m.)Built Up area: 241 ...
# 3         24300.0  2572.0                   Carpet area: 2880 (267.56 sq.m.)
# 4         11174.0  2103.0  Super Built up area 2103(195.38 sq.m.)Built Up...
#
# ...

# %%
df.shape
# Out:
# (3677, 23)

# %%
df.columns
# Out:
# Index(['property_type', 'society', 'sector', 'price', 'price_per_sqft', 'area',
#        'areaWithType', 'bedRoom', 'bathroom', 'balcony', 'floorNum', 'facing',
#        'agePossession', 'super_built_up_area', 'built_up_area', 'carpet_area',
#        'study room', 'servant room', 'store room', 'pooja room', 'others',
#        'furnishing_type', 'luxaury_score'],
#       dtype='object')

# %%
# outlier on the basis of price column
sns.distplot(df['price'])
# Out:
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_41088\4024913878.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price'])
# C:\Users\OM CHAVAN\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='price', ylabel='Density'>

# %%
sns.boxplot(x=df['price'])
# Out:
# <Axes: xlabel='price'>

# %%
# calculate the IQR for the price column
Q1=df['price'].quantile(0.25)
Q3=df['price'].quantile(0.75)
IQR=Q3-Q1

# define bounds for outliers
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR

# Identify Outliers
outliers=df[(df['price']<lower_bound) | (df['price']>upper_bound)]

# Displaying the number of outliers and statistics
num_outliers = outliers.shape[0]
outlier_price_stats=outliers['price'].describe()

num_outliers,outlier_price_stats
# Out:
# (425,
#  count    425.000000
#  mean       9.235624
#  std        4.065259
#  min        5.460000
#  25%        6.460000
#  50%        8.000000
#  75%       10.750000
#  max       31.500000
#  Name: price, dtype: float64)

# %%
outliers.sort_values('price',ascending=False).head(10)
# Out:
#      property_type                                            society  \
# 3566         house  arjun marg/ sector- 26 phase- 1/ golf course road
# 311          house                                        independent
# 2509         house                                     dlf city plots
# 1902         house                                        independent
# 2251         house                                   suncity township
# 2215         house                             emaar the palm springs
# 1666         house                                        independent
# 2049         house                                 vipul tatvam villa
# 2756         house                             luxury dlf city floors
# 3390         house                                        independent
#
#          sector  price  price_per_sqft     area  \
# 3566  sector 26   31.5         35000.0   9000.0
# 311   sector 43   27.5         24366.0  11286.0
# 2509  sector 26   26.0         57206.0   4545.0
# ...

# %%
# on the basis of price column we can say that there are some genuine outliers but there are some data errors as well

# %% [markdown]
# # price_per_sqft

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_41088\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# C:\Users\OM CHAVAN\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
# calculate the IQR for the price_per_sqft column
Q1=df['price_per_sqft'].quantile(0.25)
Q3=df['price_per_sqft'].quantile(0.75)
IQR=Q3-Q1

# define bounds for outliers
lower_bound=Q1-1.5*IQR
upper_bound=Q3+1.5*IQR

# Identify Outliers
outliers_sqft=df[(df['price_per_sqft']<lower_bound) | (df['price_per_sqft']>upper_bound)]

# Displaying the number of outliers and statistics
num_outliers = outliers_sqft.shape[0]
outlier_sqft_stats=outliers_sqft['price_per_sqft'].describe()

num_outliers,outlier_sqft_stats
# Out:
# (354,
#  count       354.000000
#  mean      52592.612994
#  std       61150.458507
#  min       24489.000000
#  25%       28208.250000
#  50%       33368.500000
#  75%       41982.250000
#  max      600000.000000
#  Name: price_per_sqft, dtype: float64)

# %%
outliers_sqft['area']=outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)
# Out:
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_41088\283904232.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['area']=outliers_sqft['area'].apply(lambda x:x*9 if x<1000 else x)

# %%
outliers_sqft['price_per_sqft']=round((outliers_sqft['price']*10000000)/outliers_sqft['area'])
# Out:
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_41088\560949187.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outliers_sqft['price_per_sqft']=round((outliers_sqft['price']*10000000)/outliers_sqft['area'])

# %%
outliers_sqft['price_per_sqft'].describe()
# Out:
# count      354.000000
# mean     29357.906780
# std      12403.077309
# min       2723.000000
# 25%      25562.000000
# 50%      29870.500000
# 75%      35549.500000
# max      82540.000000
# Name: price_per_sqft, dtype: float64

# %%
df.update(outliers_sqft)
# Out:
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_41088\4262394064.py:1: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.update(outliers_sqft)
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_41088\4262394064.py:1: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.update(outliers_sqft)
# ...

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_41088\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# C:\Users\OM CHAVAN\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
df[df['price_per_sqft']>50000].shape
# Out:
# (13, 23)

# %%
df=df[df['price_per_sqft']<=50000]

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %% [markdown]
# # Area

# %%
sns.displot(df['area'])
# Out:
# C:\Users\OM CHAVAN\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# C:\Users\OM CHAVAN\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count      3647.000000
# mean       2947.723608
# std       23208.194102
# min         145.000000
# 25%        1262.000000
# 50%        1750.000000
# 75%        2350.000000
# max      875000.000000
# Name: area, dtype: float64

# %%
df[df['area'] > 100000]
# Out:
#      property_type                    society      sector  price  \
# 25            flat      signature the roselia   sector 95   0.45
# 1468          flat          hcbs sports ville  sohna road   0.35
# 1820          flat  signature global solera 2  sector 107   0.51
# 3249          flat            ramsons kshitij   sector 95   0.31
# 3735         house                independent   sector 50   5.00
#
#       price_per_sqft      area                           areaWithType  \
# 25               7.0  642857.0   Carpet area: 569243 (52884.41 sq.m.)
# 1468             4.0  875000.0  Built Up area: 737147 (68483.2 sq.m.)
# 1820             9.0  566667.0   Carpet area: 514396 (47788.95 sq.m.)
# 3249             5.0  620000.0    Carpet area: 607936 (56479.1 sq.m.)
# 3735           232.0  215517.0             Plot area 2(1011.71 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 25          2         2       2       2.0  South-West    New Property
# ...

# %%
df = df[df['area'] < 100000]

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_41088\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# C:\Users\OM CHAVAN\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)

# 3362, 2828, 2434, 476, 836, 2953, 1696, 1601, 358
# Out:
#      property_type                    society           sector  price  \
# 3362         house                independent        sector 26  18.40
# 204          house  ganpati heights apartment        sector 13   1.25
# 2828          flat                 rof ananda        sector 95   0.38
# 2434          flat                 rof ananda        sector 95   0.38
# 2108         house      dlf city plot phase 4        sector 28  13.00
# 476           flat              pyramid elite        sector 86   0.46
# 836           flat                 rof ananda        sector 95   0.33
# 2953          flat      signature the serenas       sohna road   0.28
# 1567         house                independent        sector 25   7.30
# 1696          flat            ramsons kshitij        sector 95   0.24
# 1601          flat                 rof ananda        sector 95   0.21
# 817          house                independent        sector 57   6.25
# ...

# %%
# 3362, 2828, 2434, 476, 836, 2953, 1696, 1601, 358 has data entry Errors

# %%
df.drop(index=[3362, 2828, 2434, 476, 836, 2953, 1696, 1601, 358], inplace=True)

# %%
df[df['area'] > 10000].sort_values('area',ascending=False)
# Out:
#      property_type                    society           sector  price  \
# 204          house  ganpati heights apartment        sector 13   1.25
# 2108         house      dlf city plot phase 4        sector 28  13.00
# 1567         house                independent        sector 25   7.30
# 817          house                independent        sector 57   6.25
# 1712         house                independent        sector 43   5.50
# 3720          flat                 godrej air        sector 85   2.50
# 1170         house       unitech aspen greens        sector 50   6.95
# 2583          flat                godrej icon       sector 88a   1.75
# 311          house                independent        sector 43  27.50
# 2829          flat             m3m golfestate        sector 65  13.20
# 438          house                independent  sohna road road   5.50
#
#       price_per_sqft     area  \
# 204            151.0  82781.0
# 2108          1992.0  65261.0
# 1567          1560.0  46795.0
# ...

# %%
df.loc[204,'area']=115*9
df.loc[2108,'area']=7250
df.loc[1567,'area']=5800
df.loc[817,'area']=2660
df.loc[1712,'area']=2850
df.loc[3720,'area']=1812
df.loc[1170,'area']=2160
df.loc[2583,'area']=1175

# %%
sns.distplot(df['area'])
# Out:
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_41088\91062565.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['area'])
# C:\Users\OM CHAVAN\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='area', ylabel='Density'>

# %%
sns.boxplot(x=df['area'])
# Out:
# <Axes: xlabel='area'>

# %%
df['area'].describe()
# Out:
# count     3624.000000
# mean      1953.718819
# std       1219.636341
# min        145.000000
# 25%       1261.000000
# 50%       1749.500000
# 75%       2332.250000
# max      11286.000000
# Name: area, dtype: float64

# %% [markdown]
# # Bedroom

# %%
sns.distplot(df['bedRoom'])
# Out:
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_41088\1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# C:\Users\OM CHAVAN\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %%
df['bedRoom'].describe()
# Out:
# count    3624.000000
# mean        3.333885
# std         1.831879
# min         1.000000
# 25%         2.000000
# 50%         3.000000
# 75%         4.000000
# max        21.000000
# Name: bedRoom, dtype: float64

# %%
df[df['bedRoom']>10].sort_values('bedRoom',ascending=False)
# Out:
#      property_type                      society      sector  price  \
# 3015         house                  independent   sector 54   5.00
# 805          house                  independent   sector 43   4.50
# 2221         house                  independent  sector 17a   3.93
# 3432         house                  independent  sector 17a   3.87
# 1810         house                private house   sector 55   7.05
# 3354         house                  independent   sector 54   5.50
# 341          house                  independent   sector 11   4.50
# 3466         house                  independent   sector 56  12.39
# 2756         house       luxury dlf city floors   sector 26  20.00
# 2385         house                  independent   sector 43  13.50
# 3631         house                  independent   sector 40  12.00
# 2120         house               dlf city plots   sector 26  20.00
# 2077         house                  independent   sector 55   9.19
# ...

# %%
df=df[df['bedRoom']<=10]

# %%
df.shape
# Out:
# (3579, 23)

# %%
sns.distplot(df['bedRoom'])
# Out:
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_41088\1691983684.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['bedRoom'])
# C:\Users\OM CHAVAN\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='bedRoom', ylabel='Density'>

# %%
sns.boxplot(x=df['bedRoom'])
# Out:
# <Axes: xlabel='bedRoom'>

# %% [markdown]
# # Bathroom

# %%
sns.boxplot(x=df['bathroom'])
# Out:
# <Axes: xlabel='bathroom'>

# %%
sns.distplot(x=df['bathroom'])
# Out:
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_41088\593171972.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(x=df['bathroom'])
# C:\Users\OM CHAVAN\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: ylabel='Density'>

# %%
 df[df['bathroom']>10].sort_values('bathroom',ascending=False)
# Out:
#      property_type               society     sector  price  price_per_sqft  \
# 812          house  adani brahma samsara  sector 60  18.02         28200.0
# 1359         house           independent  sector 24  11.00         28902.0
# 1894         house           independent  sector 39   7.00         10000.0
#
#         area                                       areaWithType  bedRoom  \
# 812   6390.0                 Built Up area: 6390 (593.65 sq.m.)        9
# 1359  3806.0  Plot area 3806.45(353.63 sq.m.)Built Up area: ...        8
# 1894  7000.0  Plot area 350(32.52 sq.m.)Built Up area: 7000 ...       10
#
#       bathroom balcony  floorNum      facing   agePossession  \
# 812         12      3+       3.0  North-East  Relatively New
# 1359        11      3+       3.0        East    Old Property
# 1894        11      3+       4.0  South-East  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# ...

# %%
df.head()
# Out:
#   property_type                                   society      sector  price  \
# 0          flat                               vatika city   sector 49   1.69
# 1          flat                  pareena coban residences  sector 99a   1.10
# 3          flat  central park resort belgravia residences   sector 48   6.25
# 4          flat                            dlf the ultima   sector 81   2.35
# 5         house                               independent    sector 4   0.67
#
#    price_per_sqft    area                                       areaWithType  \
# 0          8622.0  1960.0                   Carpet area: 1960 (182.09 sq.m.)
# 1          7096.0  1550.0  Super Built up area 1550(144 sq.m.)Carpet area...
# 3         24300.0  2572.0                   Carpet area: 2880 (267.56 sq.m.)
# 4         11174.0  2103.0  Super Built up area 2103(195.38 sq.m.)Built Up...
# 5          8557.0   783.0                          Plot area 87(72.74 sq.m.)
#
# ...

# %% [markdown]
# # super_built_up_area

# %%
sns.distplot(df['super_built_up_area'])
# Out:
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_41088\4184943455.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['super_built_up_area'])
# C:\Users\OM CHAVAN\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='super_built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['super_built_up_area'])
# Out:
# <Axes: xlabel='super_built_up_area'>

# %%
df['super_built_up_area'].describe()
# Out:
# count     1869.000000
# mean      1922.770760
# std        760.403249
# min         89.000000
# 25%       1479.000000
# 50%       1828.000000
# 75%       2215.000000
# max      10000.000000
# Name: super_built_up_area, dtype: float64

# %%
df[df['super_built_up_area']>6000]
# Out:
#      property_type                      society       sector  price  \
# 1650          flat  bestech park view grand spa    sector 81    4.7
# 3191          flat       krrish provence estate  gwal pahari    7.5
#
#       price_per_sqft     area                             areaWithType  \
# 1650          6786.0   6926.0   Super Built up area 6926(643.45 sq.m.)
# 3191          7500.0  10000.0  Super Built up area 10000(929.03 sq.m.)
#
#       bedRoom  bathroom balcony  floorNum      facing   agePossession  \
# 1650        4         4      3+      19.0       North  Relatively New
# 3191        5         6      3+      23.0  North-East  Relatively New
#
#       super_built_up_area  built_up_area  carpet_area  study room  \
# 1650               6926.0            NaN          NaN           0
# 3191              10000.0            NaN          NaN           0
#
#       servant room  store room  pooja room  others  furnishing_type  \
# ...

# %% [markdown]
# # built_up_area

# %%
sns.distplot(df['built_up_area'])
# Out:
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_41088\3494228458.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['built_up_area'])
# C:\Users\OM CHAVAN\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='built_up_area', ylabel='Density'>

# %%
sns.boxplot(x=df['built_up_area'])
# Out:
# <Axes: xlabel='built_up_area'>

# %%
df[df['built_up_area']>10000]
# Out:
#     property_type      society     sector  price  price_per_sqft     area  \
# 311         house  independent  sector 43   27.5         24366.0  11286.0
#
#                      areaWithType  bedRoom  bathroom balcony  floorNum  \
# 311  Plot area 1254(1048.5 sq.m.)        6         7      3+       3.0
#
#          facing   agePossession  super_built_up_area  built_up_area  \
# 311  North-East  Relatively New                  NaN        11286.0
#
#      carpet_area  study room  servant room  store room  pooja room  others  \
# 311          NaN           1             1           0           1       1
#
#      furnishing_type  luxaury_score
# 311                2             42

# %% [markdown]
# # carpet_area

# %%
sns.distplot(df['carpet_area'])
# Out:
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_41088\3905767603.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['carpet_area'])
# C:\Users\OM CHAVAN\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='carpet_area', ylabel='Density'>

# %%
sns.boxplot(x=df['carpet_area'])
# Out:
# <Axes: xlabel='carpet_area'>

# %%
df[df['carpet_area']>10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 2829          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
# 3720          flat      godrej air  sector 85    2.5          1379.0   1812.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 2829  Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
# 3720  Carpet area: 18122 (1683.59 sq.m.)        4         5      3+      16.0
#
#           facing   agePossession  super_built_up_area  built_up_area  \
# 2829       North  Moderately Old                  NaN            NaN
# 3720  North-East       Undefined                  NaN            NaN
#
#       carpet_area  study room  servant room  store room  pooja room  others  \
# 2829      11000.0           0             1           0           0       0
# 3720      18122.0           1             0           0           1       1
#
#       furnishing_type  luxaury_score
# ...

# %%
df.loc[3720,'carpet_area']=1812

# %%
df[df['carpet_area']>10000]
# Out:
#      property_type         society     sector  price  price_per_sqft     area  \
# 2829          flat  m3m golfestate  sector 65   13.2         12000.0  11000.0
#
#                             areaWithType  bedRoom  bathroom balcony  floorNum  \
# 2829  Carpet area: 11000 (1021.93 sq.m.)        4         4       3      13.0
#
#      facing   agePossession  super_built_up_area  built_up_area  carpet_area  \
# 2829  North  Moderately Old                  NaN            NaN      11000.0
#
#       study room  servant room  store room  pooja room  others  \
# 2829           0             1           0           0       0
#
#       furnishing_type  luxaury_score
# 2829                0             60

# %%
df.head()
# Out:
#   property_type                                   society      sector  price  \
# 0          flat                               vatika city   sector 49   1.69
# 1          flat                  pareena coban residences  sector 99a   1.10
# 3          flat  central park resort belgravia residences   sector 48   6.25
# 4          flat                            dlf the ultima   sector 81   2.35
# 5         house                               independent    sector 4   0.67
#
#    price_per_sqft    area                                       areaWithType  \
# 0          8622.0  1960.0                   Carpet area: 1960 (182.09 sq.m.)
# 1          7096.0  1550.0  Super Built up area 1550(144 sq.m.)Carpet area...
# 3         24300.0  2572.0                   Carpet area: 2880 (267.56 sq.m.)
# 4         11174.0  2103.0  Super Built up area 2103(195.38 sq.m.)Built Up...
# 5          8557.0   783.0                          Plot area 87(72.74 sq.m.)
#
# ...

# %% [markdown]
# # luxaury_score

# %%
sns.distplot(df['luxaury_score'])
# Out:
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_41088\3683985748.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['luxaury_score'])
# C:\Users\OM CHAVAN\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='luxaury_score', ylabel='Density'>

# %%
sns.boxplot(x=df['luxaury_score'])
# Out:
# <Axes: xlabel='luxaury_score'>

# %%
df.shape
# Out:
# (3579, 23)

# %%
df['price_per_sqft'] = round((df['price']*10000000)/df['area'])
# Out:
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_41088\3958460563.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['price_per_sqft'] = round((df['price']*10000000)/df['area'])

# %%
sns.distplot(df['price_per_sqft'])
# Out:
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_41088\2186227091.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['price_per_sqft'])
# C:\Users\OM CHAVAN\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# <Axes: xlabel='price_per_sqft', ylabel='Density'>

# %%
sns.boxplot(x=df['price_per_sqft'])
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
df[df['price_per_sqft']>42000]
# Out:
#      property_type                       society      sector  price  \
# 42           house                   independent   sector 25   13.0
# 173          house                dlf city plots   sector 26   19.0
# 672          house                   independent   sector 26   19.0
# 710          house  sushant lok 1 builder floors   sector 43   13.0
# 726          house                   independent   sector 28   12.0
# 894          house                   independent   sector 55    5.0
# 2684         house                   independent   sector 43    9.5
# 3251         house                   independent  sector 105    9.9
# 3390         house                   independent   sector 26   20.0
#
#       price_per_sqft    area  \
# 42           45710.0  2844.0
# 173          42054.0  4518.0
# 672          42222.0  4500.0
# 710          48148.0  2700.0
# 726          42194.0  2844.0
# 894          44444.0  1125.0
# 2684         42222.0  2250.0
# 3251         49500.0  2000.0
# ...

# %%
x=df[df['price_per_sqft']<=20000]

# %%
(x['area']/x['bedRoom']).quantile(0.05)
# Out:
# 251.70000000000005

# %%
df[(df['area']/df['bedRoom'])<250].sample(5)
# Out:
#      property_type                  society      sector  price  \
# 3287         house              independent    sector 7   0.90
# 1307         house           uppal southend   sector 49   3.75
# 2768         house              independent     manesar   1.10
# 2301          flat  signature global solera  sector 107   0.27
# 3719         house     housing board colony  sector 110   2.10
#
#       price_per_sqft    area                       areaWithType  bedRoom  \
# 3287         10000.0   900.0         Plot area 100(83.61 sq.m.)        6
# 1307         25562.0  1467.0  Built Up area: 163 (136.29 sq.m.)        6
# 2768          6173.0  1782.0       Plot area 1782(165.55 sq.m.)        8
# 2301          5521.0   489.0     Carpet area: 489 (45.43 sq.m.)        2
# 3719         23333.0   900.0         Plot area 100(83.61 sq.m.)        8
#
#       bathroom balcony  floorNum      facing   agePossession  \
# 3287         4       3       3.0  North-East    Old Property
# ...

# %%
sns.lmplot(data=df,x='area',y='bedRoom')
# Out:
# C:\Users\OM CHAVAN\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df['area_room_ratio']=df['area']/df['bedRoom']

# %%
(df[df['area_room_ratio']<250])['bedRoom'].value_counts()
# Out:
# bedRoom
# 2     47
# 3     32
# 5     28
# 6     17
# 4     17
# 9     15
# 8     11
# 7      8
# 10     8
# Name: count, dtype: int64

# %%
df=df[df['area_room_ratio'] > 100]

# %%
outlier_df=df[(df['area_room_ratio']<250) & (df['bedRoom'] >3)]

# %%
outlier_df['bedRoom']=round(outlier_df['bedRoom']/outlier_df['floorNum'])
# Out:
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_41088\3823887811.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   outlier_df['bedRoom']=round(outlier_df['bedRoom']/outlier_df['floorNum'])

# %%
df.update(outlier_df)
# Out:
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_41088\1617301329.py:1: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.update(outlier_df)
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_41088\1617301329.py:1: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.update(outlier_df)
# ...

# %%
df['area_room_ratio']=df['area']/df['bedRoom']
# Out:
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_41088\2419531321.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['area_room_ratio']=df['area']/df['bedRoom']

# %%
df[(df['area_room_ratio']<250) & (df['bedRoom'] >4)]
# Out:
#      property_type               society            sector  price  \
# 175          house           independent          sector 2   0.98
# 306          house           independent         sector 12   2.50
# 787          house           independent           manesar   0.80
# 797          house              shivpuri          sector 7   2.80
# 1425         house           independent          sector 7   1.16
# 1637         house           independent  sector 3 phase 2   1.10
# 1979         house           independent  sector 3 phase 2   0.85
# 2581         house  bhim nagar, sector 6          sector 6   0.85
# 2592         house           independent        sector 105   1.10
# 2768         house           independent           manesar   1.10
# 2889         house           independent         sector 12   0.65
# 3268         house           independent         sector 11   3.50
# 3706         house           independent         sector 17   0.32
#
#       price_per_sqft    area  \
# ...

# %%
df[(df['area_room_ratio']<250) & (df['bedRoom'] >4)].shape
# Out:
# (13, 24)

# %%
df.shape
# Out:
# (3560, 24)

# %%
df=df[~((df['area_room_ratio']<250) & (df['bedRoom'] >4))]

# %%
sns.lmplot(data=df,x='area',y='bedRoom')
# Out:
# C:\Users\OM CHAVAN\AppData\Local\Programs\Python\Python311\Lib\site-packages\seaborn\axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)

# %%
df.shape
# Out:
# (3547, 24)

# %%
df.head()
# Out:
#   property_type                                   society      sector  price  \
# 0          flat                               vatika city   sector 49   1.69
# 1          flat                  pareena coban residences  sector 99a   1.10
# 3          flat  central park resort belgravia residences   sector 48   6.25
# 4          flat                            dlf the ultima   sector 81   2.35
# 5         house                               independent    sector 4   0.67
#
#    price_per_sqft    area                                       areaWithType  \
# 0          8622.0  1960.0                   Carpet area: 1960 (182.09 sq.m.)
# 1          7097.0  1550.0  Super Built up area 1550(144 sq.m.)Carpet area...
# 3         24300.0  2572.0                   Carpet area: 2880 (267.56 sq.m.)
# 4         11175.0  2103.0  Super Built up area 2103(195.38 sq.m.)Built Up...
# 5          8557.0   783.0                          Plot area 87(72.74 sq.m.)
#
# ...

# %%
df.to_csv('gurgaon_properties_outlier_treated.csv',index=False)
