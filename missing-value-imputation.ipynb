# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pd.set_option('display.max_columns',None)

# %%
df=pd.read_csv('gurgaon_properties_outlier_treated.csv')

# %%
df.head()
# Out:
#   property_type                                   society      sector  price  \
# 0          flat                               vatika city   sector 49   1.69
# 1          flat                  pareena coban residences  sector 99a   1.10
# 2          flat  central park resort belgravia residences   sector 48   6.25
# 3          flat                            dlf the ultima   sector 81   2.35
# 4         house                               independent    sector 4   0.67
#
#    price_per_sqft    area                                       areaWithType  \
# 0          8622.0  1960.0                   Carpet area: 1960 (182.09 sq.m.)
# 1          7097.0  1550.0  Super Built up area 1550(144 sq.m.)Carpet area...
# 2         24300.0  2572.0                   Carpet area: 2880 (267.56 sq.m.)
# 3         11175.0  2103.0  Super Built up area 2103(195.38 sq.m.)Built Up...
# 4          8557.0   783.0                          Plot area 87(72.74 sq.m.)
#
# ...

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                139
# facing                 1011
# agePossession             0
# super_built_up_area    1678
# built_up_area          1960
# carpet_area            1711
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxaury_score             0
# area_room_ratio           0
# dtype: int64

# %% [markdown]
# # built_up_area

# %%
sns.scatterplot(x=df['built_up_area'],y=df['super_built_up_area'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='super_built_up_area'>

# %%
df[((df['super_built_up_area'].isnull())&(df['built_up_area'].isnull())&(df['carpet_area'].isnull()))]
# Out:
# Empty DataFrame
# Columns: [property_type, society, sector, price, price_per_sqft, area, areaWithType, bedRoom, bathroom, balcony, floorNum, facing, agePossession, super_built_up_area, built_up_area, carpet_area, study room, servant room, store room, pooja room, others, furnishing_type, luxaury_score, area_room_ratio]
# Index: []

# %%
all_present_df=df[~((df['super_built_up_area'].isnull()) | (df['built_up_area'].isnull()) | (df['carpet_area'].isnull()))]

# %%
all_present_df
# Out:
#      property_type                   society      sector  price  \
# 3             flat            dlf the ultima   sector 81   2.35
# 9             flat  emaar mgf the palm drive   sector 66   2.80
# 13            flat  signature andour heights   sector 71   0.37
# 17            flat            dlf the ultima   sector 81   2.40
# 19            flat               ss the leaf   sector 85   1.98
# ...            ...                       ...         ...    ...
# 3525          flat    guru gram haryana cghs   sector 56   1.39
# 3529          flat                paras dews  sector 106   1.50
# 3530          flat                ireo skyon   sector 60   3.05
# 3533          flat               ss the leaf   sector 85   2.20
# 3542          flat               ats triumph  sector 104   1.83
#
#       price_per_sqft    area  \
# 3            11175.0  2103.0
# 9            14359.0  1950.0
# 13            7400.0   500.0
# 17           11257.0  2132.0
# 19            8257.0  2398.0
# ...

# %%
super_built_up_ratio=(all_present_df['super_built_up_area']/all_present_df['built_up_area']).median()

# %%
carpet_built_up_ratio=(all_present_df['carpet_area']/all_present_df['built_up_area']).median()

# %%
print(super_built_up_ratio,carpet_built_up_ratio)
# Out:
# 1.105263157894737 0.9

# %%
sbc_df=df[~(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & ~(df['carpet_area'].isnull())]

# %%
sbc_df.head()
# Out:
#    property_type                   society      sector  price  price_per_sqft  \
# 1           flat  pareena coban residences  sector 99a    1.1          7097.0
# 14          flat   shree vardhman victoria   sector 70    1.5          7692.0
# 16          flat             m3m woodshire  sector 107    1.3         10815.0
# 20          flat               ss the leaf   sector 85    1.3          7780.0
# 27          flat                m3m merlin   sector 67    2.8         13679.0
#
#       area                                       areaWithType  bedRoom  \
# 1   1550.0  Super Built up area 1550(144 sq.m.)Carpet area...        2
# 14  1950.0  Super Built up area 1950(181.16 sq.m.)Carpet a...        3
# 16  1202.0  Super Built up area 1943(180.51 sq.m.)Carpet a...        3
# 20  1671.0  Super Built up area 1671(155.24 sq.m.)Carpet a...        2
# 27  2047.0  Super Built up area 2047(190.17 sq.m.)Carpet a...        3
#
#     bathroom balcony  floorNum      facing   agePossession  \
# ...

# %%
# made average of 'super_built_up_area' and 'carpet_area' as an average for 'built_up_area'

# %%
sbc_df['built_up_area'].fillna(round(((sbc_df['super_built_up_area']/1.105) + (sbc_df['carpet_area']/0.9))/2),inplace=True)
# Out:
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_35032\1215074969.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sbc_df['built_up_area'].fillna(round(((sbc_df['super_built_up_area']/1.105) + (sbc_df['carpet_area']/0.9))/2),inplace=True)
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_35032\1215074969.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# ...

# %%
df.update(sbc_df)
# Out:
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_35032\3129191992.py:1: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.update(sbc_df)
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_35032\3129191992.py:1: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.update(sbc_df)
# ...

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                139
# facing                 1011
# agePossession             0
# super_built_up_area    1678
# built_up_area          1541
# carpet_area            1711
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxaury_score             0
# area_room_ratio           0
# dtype: int64

# %%
# rows where 'super_built_up_area' is available but the 'carpet_area' is  and 'built_up_area' is null

# %%
sb_df=df[~(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & (df['carpet_area'].isnull())]

# %%
sb_df.head()
# Out:
#    property_type                 society      sector  price  price_per_sqft  \
# 6           flat        ansal heights 86   sector 86   0.78          5735.0
# 7           flat  conscient heritage max  sector 102   2.15         10005.0
# 10          flat           sbtl caladium  sector 109   1.26          6542.0
# 18          flat             greenopolis   sector 89   0.80          4819.0
# 21          flat   alpha corp gurgaonone   sector 84   1.20          9449.0
#
#       area                            areaWithType  bedRoom  bathroom balcony  \
# 6   1360.0  Super Built up area 1360(126.35 sq.m.)        2         2       1
# 7   2149.0  Super Built up area 2149(199.65 sq.m.)        3         4      3+
# 10  1926.0  Super Built up area 1880(174.66 sq.m.)        3         2       3
# 18  1660.0  Super Built up area 1660(154.22 sq.m.)        2         3       3
# 21  1270.0  Super Built up area 1270(117.99 sq.m.)        2         2       1
#
# ...

# %%
sb_df['built_up_area'].fillna(round(sb_df['super_built_up_area']/1.105),inplace=True)
# Out:
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_35032\1714170073.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   sb_df['built_up_area'].fillna(round(sb_df['super_built_up_area']/1.105),inplace=True)
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_35032\1714170073.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df.update(sb_df)
# Out:
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_35032\273999481.py:1: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.update(sb_df)
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_35032\273999481.py:1: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.update(sb_df)
# ...

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                139
# facing                 1011
# agePossession             0
# super_built_up_area    1678
# built_up_area           670
# carpet_area            1711
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxaury_score             0
# area_room_ratio           0
# dtype: int64

# %%
# rows where 'super_built_up_area' is null but the 'carpet_area' is  there and calculate 'built_up_area'

# %%
c_df=df[(df['super_built_up_area'].isnull()) & (df['built_up_area'].isnull()) & ~(df['carpet_area'].isnull())]

# %%
c_df['built_up_area'].fillna(round(c_df['carpet_area']/0.9),inplace=True)
# Out:
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_35032\2136919732.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   c_df['built_up_area'].fillna(round(c_df['carpet_area']/0.9),inplace=True)
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_35032\2136919732.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# ...

# %%
df.update(c_df)
# Out:
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_35032\108363553.py:1: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.update(c_df)
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_35032\108363553.py:1: FutureWarning: Downcasting behavior in Series and DataFrame methods 'where', 'mask', and 'clip' is deprecated. In a future version this will not infer object dtypes or cast all-round floats to integers. Instead call result.infer_objects(copy=False) for object inference, or cast round floats explicitly. To opt-in to the future behavior, set `pd.set_option('future.no_silent_downcasting', True)`
#   df.update(c_df)
# ...

# %%
df.isnull().sum()
# Out:
# property_type             0
# society                   1
# sector                    0
# price                     0
# price_per_sqft            0
# area                      0
# areaWithType              0
# bedRoom                   0
# bathroom                  0
# balcony                   0
# floorNum                139
# facing                 1011
# agePossession             0
# super_built_up_area    1678
# built_up_area             0
# carpet_area            1711
# study room                0
# servant room              0
# store room                0
# pooja room                0
# others                    0
# furnishing_type           0
# luxaury_score             0
# area_room_ratio           0
# dtype: int64

# %%
sns.scatterplot(x=df['built_up_area'],y=df['price'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='price'>

# %%
anomaly_df=df[(df['built_up_area']<2000) & (df['price']>2.5)][['price','area','built_up_area']]

# %%
anomaly_df.head()
# Out:
#     price    area  built_up_area
# 9    2.80  1950.0         1920.0
# 11   2.95  1449.0         1000.0
# 15   4.25  1350.0         1350.0
# 27   2.80  2047.0         1971.0
# 28   9.85  3323.0          418.0

# %%
anomaly_df['built_up_area']=anomaly_df['area']

# %%
df.update(anomaly_df)

# %%
sns.scatterplot(x=df['built_up_area'],y=df['price'])
# Out:
# <Axes: xlabel='built_up_area', ylabel='price'>

# %%
df.drop(columns=['area','areaWithType','super_built_up_area','carpet_area','area_room_ratio'],inplace=True)

# %%
df.head()
# Out:
#   property_type                                   society      sector  price  \
# 0          flat                               vatika city   sector 49   1.69
# 1          flat                  pareena coban residences  sector 99a   1.10
# 2          flat  central park resort belgravia residences   sector 48   6.25
# 3          flat                            dlf the ultima   sector 81   2.35
# 4         house                               independent    sector 4   0.67
#
#    price_per_sqft  bedRoom  bathroom balcony  floorNum      facing  \
# 0          8622.0        3         3       3       3.0       North
# 1          7097.0        2         2       3       9.0  North-East
# 2         24300.0        3         5      3+       5.0  South-East
# 3         11175.0        3         3      3+      14.0       South
# 4          8557.0        3         2       1       1.0       South
#
#     agePossession  built_up_area  study room  servant room  store room  \
# ...

# %%
df.isnull().sum()
# Out:
# property_type         0
# society               1
# sector                0
# price                 0
# price_per_sqft        0
# bedRoom               0
# bathroom              0
# balcony               0
# floorNum            139
# facing             1011
# agePossession         0
# built_up_area         0
# study room            0
# servant room          0
# store room            0
# pooja room            0
# others                0
# furnishing_type       0
# luxaury_score         0
# dtype: int64

# %%
temp_df=df[df['floorNum'].isnull()]

# %%
temp_df[temp_df['property_type']=='flat']
# Out:
#      property_type                society      sector  price  price_per_sqft  \
# 73            flat             m3m merlin   sector 67   2.98         14558.0
# 74            flat  m3m one key resiments   sector 67   0.80         13115.0
# 97            flat                    NaN   sector 78   0.60          3692.0
# 103           flat     supertech araville   sector 79   0.78          6023.0
# 215           flat           tulip violet   sector 69   1.75          9459.0
# ...            ...                    ...         ...    ...             ...
# 3472          flat        raheja vedaanta  sector 108   1.25          5682.0
# 3483          flat           tulip violet   sector 69   1.70         10773.0
# 3510          flat         vipul belmonte   sector 53   6.50         21922.0
# 3514          flat          orchid petals   sector 49   2.45         11887.0
# 3522          flat          vipul lavanya   sector 81   0.60          6667.0
#
# ...

# %%
temp_df[temp_df['property_type']=='house']
# Out:
#      property_type                  society     sector  price  price_per_sqft  \
# 39           house              independent  sector 25  13.00         45710.0
# 361          house              independent  sector 26   4.60         12198.0
# 907          house     dlf new town heights  sector 86   2.47          7719.0
# 1134         house               jacob pura  sector 12   0.35          9722.0
# 1334         house        ansal sushant lok  sector 43  10.50         27911.0
# 1689         house              independent   sector 7   6.50         15046.0
# 1827         house  ansal sushant lok plots  sector 43   3.30         26570.0
# 1976         house              independent   sector 4   4.12          8889.0
# 1985         house       emaar mgf marbella  sector 66   9.00         21251.0
# 2094         house              independent  sector 24   1.45          2984.0
# 2163         house              independent   sector 2   5.60         17284.0
# ...

# %%
# replacing floor number of houses with median floor number

# %%
df[df['property_type']=='house']['floorNum'].median()
# Out:
# 2.0

# %%
df['floorNum'].fillna(2.0,inplace=True)
# Out:
# C:\Users\OM CHAVAN\AppData\Local\Temp\ipykernel_35032\15612474.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df['floorNum'].fillna(2.0,inplace=True)

# %%
df.isnull().sum()
# Out:
# property_type         0
# society               1
# sector                0
# price                 0
# price_per_sqft        0
# bedRoom               0
# bathroom              0
# balcony               0
# floorNum              0
# facing             1011
# agePossession         0
# built_up_area         0
# study room            0
# servant room          0
# store room            0
# pooja room            0
# others                0
# furnishing_type       0
# luxaury_score         0
# dtype: int64

# %% [markdown]
# # Facing

# %%
df['facing'].value_counts().plot(kind='pie',autopct='%0.2f%%')
# Out:
# <Axes: ylabel='count'>

# %%
(df['facing'].isnull().sum()/df.shape)[0]
# Out:
# 0.2850296024809698

# %%
df.drop(columns=['facing'],inplace=True)

# %%
df.head()
# Out:
#   property_type                                   society      sector  price  \
# 0          flat                               vatika city   sector 49   1.69
# 1          flat                  pareena coban residences  sector 99a   1.10
# 2          flat  central park resort belgravia residences   sector 48   6.25
# 3          flat                            dlf the ultima   sector 81   2.35
# 4         house                               independent    sector 4   0.67
#
#    price_per_sqft  bedRoom  bathroom balcony  floorNum   agePossession  \
# 0          8622.0        3         3       3       3.0  Moderately Old
# 1          7097.0        2         2       3       9.0    New Property
# 2         24300.0        3         5      3+       5.0  Moderately Old
# 3         11175.0        3         3      3+      14.0  Relatively New
# 4          8557.0        3         2       1       1.0  Moderately Old
#
# ...

# %%
df.isnull().sum()
# Out:
# property_type      0
# society            1
# sector             0
# price              0
# price_per_sqft     0
# bedRoom            0
# bathroom           0
# balcony            0
# floorNum           0
# agePossession      0
# built_up_area      0
# study room         0
# servant room       0
# store room         0
# pooja room         0
# others             0
# furnishing_type    0
# luxaury_score      0
# dtype: int64

# %%
df[df['society'].isnull()]
# Out:
#    property_type society     sector  price  price_per_sqft  bedRoom  bathroom  \
# 97          flat     NaN  sector 78    0.6          3692.0        2         2
#
#    balcony  floorNum       agePossession  built_up_area  study room  \
# 97       0       2.0  Under Construction         1625.0           0
#
#     servant room  store room  pooja room  others  furnishing_type  \
# 97             0           0           0       0                0
#
#     luxaury_score
# 97              0

# %%
df.drop(index=[97],inplace=True)

# %%
df.isnull().sum()
# Out:
# property_type      0
# society            0
# sector             0
# price              0
# price_per_sqft     0
# bedRoom            0
# bathroom           0
# balcony            0
# floorNum           0
# agePossession      0
# built_up_area      0
# study room         0
# servant room       0
# store room         0
# pooja room         0
# others             0
# furnishing_type    0
# luxaury_score      0
# dtype: int64

# %% [markdown]
# # agePossession

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1601
# New Property           555
# Moderately Old         544
# Undefined              422
# Old Property           293
# Under Construction     130
# undefined                1
# Name: count, dtype: int64

# %%
df['agePossession']=df['agePossession'].replace('undefined','Undefined')

# %%
df[df['agePossession']=='Undefined']
# Out:
#      property_type                      society      sector  price  \
# 22            flat            sidhartha ncr one   sector 95   0.56
# 24            flat                 tulip petals   sector 89   1.10
# 32           house               ats tourmaline  sector 109   1.87
# 35            flat               assotech blith   sector 99   1.90
# 74            flat        m3m one key resiments   sector 67   0.80
# ...            ...                          ...         ...    ...
# 3507          flat  godrej nature plus serenity   sector 33   1.45
# 3509          flat        signature global park  sohna road   0.75
# 3540          flat             smart world gems   sector 89   1.16
# 3541          flat                       godrej   sector 79   2.50
# 3544          flat       dlf garden city floors   sector 92   1.70
#
#       price_per_sqft  bedRoom  bathroom balcony  floorNum agePossession  \
# 22            4106.0        2         2       2      10.0     Undefined
# ...

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1601
# New Property           555
# Moderately Old         544
# Undefined              423
# Old Property           293
# Under Construction     130
# Name: count, dtype: int64

# %%
def mode_based_imputation(row):
    if row['agePossession'] == 'Undefined':
        mode_value = df[(df['sector'] == row['sector']) & (df['property_type'] == row['property_type'])]['agePossession'].mode()
        # If mode_value is empty (no mode found), return NaN, otherwise return the mode
        if not mode_value.empty:
            return mode_value.iloc[0] 
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
df['agePossession'] = df.apply(mode_based_imputation,axis=1)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1779
# New Property           649
# Moderately Old         585
# Old Property           330
# Under Construction     132
# Undefined               71
# Name: count, dtype: int64

# %%
def mode_based_imputation2(row):
    if row['agePossession'] == 'Undefined':
        mode_value = df[(df['sector'] == row['sector'])]['agePossession'].mode()
        # If mode_value is empty (no mode found), return NaN, otherwise return the mode
        if not mode_value.empty:
            return mode_value.iloc[0] 
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
df['agePossession'] = df.apply(mode_based_imputation2,axis=1)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1792
# New Property           654
# Moderately Old         592
# Old Property           341
# Under Construction     132
# Undefined               35
# Name: count, dtype: int64

# %%
def mode_based_imputation3(row):
    if row['agePossession'] == 'Undefined':
        mode_value = df[(df['property_type'] == row['property_type'])]['agePossession'].mode()
        # If mode_value is empty (no mode found), return NaN, otherwise return the mode
        if not mode_value.empty:
            return mode_value.iloc[0] 
        else:
            return np.nan
    else:
        return row['agePossession']

# %%
df['agePossession'] = df.apply(mode_based_imputation3,axis=1)

# %%
df['agePossession'].value_counts()
# Out:
# agePossession
# Relatively New        1804
# New Property           654
# Moderately Old         615
# Old Property           341
# Under Construction     132
# Name: count, dtype: int64

# %%
# df[df['agePossession']=='undefined']

# %%
df.isnull().sum()
# Out:
# property_type      0
# society            0
# sector             0
# price              0
# price_per_sqft     0
# bedRoom            0
# bathroom           0
# balcony            0
# floorNum           0
# agePossession      0
# built_up_area      0
# study room         0
# servant room       0
# store room         0
# pooja room         0
# others             0
# furnishing_type    0
# luxaury_score      0
# dtype: int64

# %%
df.to_csv('gurgaon_properties_missing_value_imputation.csv',index=False)

# %%
df.shape
# Out:
# (3546, 18)
