# %%
# import requests
# from bs4 import BeautifulSoup
# import pandas as pd

# # Base URL for Google Search
# BASE_URL = "https://www.google.com/search?q="

# # Headers to simulate a real browser visit
# HEADERS = {
#     "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
# }

# # Function to scrape latitude and longitude
# def get_coordinates(sector):
#     search_term = f"sector {sector} gurgaon longitude & latitude"
#     response = requests.get(BASE_URL + search_term, headers=HEADERS)

#     if response.status_code == 200:
#         soup = BeautifulSoup(response.content, 'html.parser')
#         coordinates_div = soup.find("div", class_="wvKXQ")  # This class might need to be updated
#         if coordinates_div:
#             return coordinates_div.text
#     return None

# # List to hold the data
# data = []

# # Iterate over sectors and fetch coordinates
# for sector in range(1, 116):
#     coordinates = get_coordinates(sector)
#     data.append({"Sector": f"Sector {sector}", "Coordinates": coordinates})
#     print(f"Fetched coordinates for Sector {sector}: {coordinates}")

# # Create a DataFrame from the data
# df = pd.DataFrame(data)

# # Save DataFrame to a CSV file
# df.to_csv("gurgaon_sectors_coordinates.csv", index=False)

# print("Coordinates fetched and saved to gurgaon_sectors_coordinates.csv")

# %%
# import requests
# from bs4 import BeautifulSoup
# import pandas as pd

# # Base URL for Google Search
# BASE_URL = "https://www.google.com/search?q="

# # Headers to simulate a real browser visit
# HEADERS = {
#     "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
# }

# # Function to scrape latitude and longitude
# def get_coordinates(sector):
#     search_term = f"sector {sector} gurgaon longitude & latitude"
#     response = requests.get(BASE_URL + search_term, headers=HEADERS)

#     if response.status_code == 200:
#         soup = BeautifulSoup(response.content, 'html.parser')
#         coordinates_divs = soup.find_all("div", class_="wvKXQ")
#         for div in coordinates_divs:
#             if '°' in div.text:  # Ensure it's the correct div containing coordinates
#                 return div.text
#     return None

# # List to hold the data
# data = []

# # Iterate over sectors and fetch coordinates
# for sector in range(1, 116):
#     coordinates = get_coordinates(sector)
#     data.append({"Sector": f"Sector {sector}", "Coordinates": coordinates})
#     print(f"Fetched coordinates for Sector {sector}: {coordinates}")

# # Create a DataFrame from the data
# df = pd.DataFrame(data)

# # Save DataFrame to a CSV file
# df.to_csv("gurgaon_sectors_coordinates.csv", index=False)

# print("Coordinates fetched and saved to gurgaon_sectors_coordinates.csv")

# %%
from bs4 import BeautifulSoup
import pandas as pd

# Base URL for Google Search
BASE_URL = "https://www.google.com/search?q="

# Headers to simulate a real browser visit
HEADERS = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/91.0.4472.124 Safari/537.36"
}


# Function to scrape latitude and longitude
def get_coordinates(sector):
    search_term = f"sector {sector} gurgaon longitude & latitude"
    response = requests.get(BASE_URL + search_term, headers=HEADERS)

    if response.status_code == 200:
        soup = BeautifulSoup(response.content, 'html.parser')
        coordinates_div = soup.find("div", class_="Z0LcW t2b5Cf")
        if coordinates_div:
            return coordinates_div.text
    return None


# List to hold the data
data = []

# Iterate over sectors and fetch coordinates
for sector in range(1, 116):
    coordinates = get_coordinates(sector)
    data.append({"Sector": f"Sector {sector}", "Coordinates": coordinates})
    print(f"Fetched coordinates for Sector {sector}: {coordinates}")

# Create a DataFrame from the data
df = pd.DataFrame(data)

# Save DataFrame to a CSV file
df.to_csv("gurgaon_sectors_coordinates1.csv", index=False)

print("Coordinates fetched and saved to gurgaon_sectors_coordinates1.csv")
# Out:
# Fetched coordinates for Sector 1: 28.5176° N, 77.0454° E
# Fetched coordinates for Sector 2: 28.5095° N, 77.0320° E
# Fetched coordinates for Sector 3: 28.4909° N, 77.0176° E
# Fetched coordinates for Sector 4: None
# Fetched coordinates for Sector 5: None
# Fetched coordinates for Sector 6: 28.4745° N, 77.0262° E
# Fetched coordinates for Sector 7: None
# Fetched coordinates for Sector 8: 28.3738° N, 76.8970° E
# Fetched coordinates for Sector 9: None
# Fetched coordinates for Sector 10: None
# Fetched coordinates for Sector 11: None
# Fetched coordinates for Sector 12: 28.4723° N, 77.0320° E
# Fetched coordinates for Sector 13: 28.4757° N, 77.0392° E
# Fetched coordinates for Sector 14: None
# Fetched coordinates for Sector 15: None
# Fetched coordinates for Sector 16: 28.4684° N, 77.0521° E
# Fetched coordinates for Sector 17: None
# Fetched coordinates for Sector 18: 28.4908° N, 77.0690° E
# Fetched coordinates for Sector 19: 28.5040° N, 77.0748° E
# Fetched coordinates for Sector 20: None
# Fetched coordinates for Sector 21: 28.5134° N, 77.0723° E
# Fetched coordinates for Sector 22: None
# Fetched coordinates for Sector 23: None
# Fetched coordinates for Sector 24: 28.4939° N, 77.1038° E
# Fetched coordinates for Sector 25: 28.4844° N, 77.0860° E
# Fetched coordinates for Sector 26: 28.4757° N, 77.1032° E
# Fetched coordinates for Sector 27: None
# Fetched coordinates for Sector 28: None
# Fetched coordinates for Sector 29: None
# Fetched coordinates for Sector 30: None
# Fetched coordinates for Sector 31: None
# Fetched coordinates for Sector 32: None
# Fetched coordinates for Sector 33: None
# Fetched coordinates for Sector 34: None
# Fetched coordinates for Sector 35: 28.4155° N, 77.0022° E
# Fetched coordinates for Sector 36: 28.4160° N, 76.9914° E
# Fetched coordinates for Sector 37: 28.4375° N, 76.9999° E
# Fetched coordinates for Sector 38: None
# Fetched coordinates for Sector 39: None
# Fetched coordinates for Sector 40: None
# Fetched coordinates for Sector 41: None
# Fetched coordinates for Sector 42: None
# Fetched coordinates for Sector 43: None
# Fetched coordinates for Sector 44: None
# Fetched coordinates for Sector 45: None
# Fetched coordinates for Sector 46: None
# Fetched coordinates for Sector 47: 28.4276° N, 77.0492° E
# Fetched coordinates for Sector 48: 28.4177° N, 77.0359° E
# Fetched coordinates for Sector 49: None
# Fetched coordinates for Sector 50: None
# Fetched coordinates for Sector 51: 28.4320° N, 77.0686° E
# Fetched coordinates for Sector 52: 28.4379° N, 77.0785° E
# Fetched coordinates for Sector 53: None
# Fetched coordinates for Sector 54: None
# Fetched coordinates for Sector 55: None
# Fetched coordinates for Sector 56: 28.4245° N, 77.0991° E
# Fetched coordinates for Sector 57: 28.4232° N, 77.0752° E
# Fetched coordinates for Sector 58: None
# Fetched coordinates for Sector 59: None
# Fetched coordinates for Sector 60: None
# Fetched coordinates for Sector 61: None
# Fetched coordinates for Sector 62: None
# Fetched coordinates for Sector 63: None
# Fetched coordinates for Sector 64: 28.3903° N, 77.0752° E
# Fetched coordinates for Sector 65: None
# Fetched coordinates for Sector 66: 28.3925° N, 77.0541° E
# Fetched coordinates for Sector 67: None
# Fetched coordinates for Sector 68: None
# Fetched coordinates for Sector 69: None
# Fetched coordinates for Sector 70: None
# Fetched coordinates for Sector 71: None
# Fetched coordinates for Sector 72: None
# Fetched coordinates for Sector 73: None
# Fetched coordinates for Sector 74: None
# Fetched coordinates for Sector 75: None
# Fetched coordinates for Sector 76: 28.3935° N, 76.9888° E
# Fetched coordinates for Sector 77: None
# Fetched coordinates for Sector 78: None
# Fetched coordinates for Sector 79: 28.3624° N, 76.9787° E
# Fetched coordinates for Sector 80: None
# Fetched coordinates for Sector 81: None
# Fetched coordinates for Sector 82: None
# Fetched coordinates for Sector 83: None
# Fetched coordinates for Sector 84: None
# Fetched coordinates for Sector 85: None
# Fetched coordinates for Sector 86: None
# Fetched coordinates for Sector 87: 28.3936° N, 76.9312° E
# Fetched coordinates for Sector 88: 28.4220° N, 76.9571° E
# Fetched coordinates for Sector 89: 28.4253° N, 76.9439° E
# Fetched coordinates for Sector 90: 28.4085° N, 76.9369° E
# Fetched coordinates for Sector 91: 28.4014° N, 76.9225° E
# Fetched coordinates for Sector 92: None
# Fetched coordinates for Sector 93: 28.4153° N, 76.9326° E
# Fetched coordinates for Sector 94: None
# Fetched coordinates for Sector 95: None
# Fetched coordinates for Sector 96: 28.3966° N, 76.8735° E
# Fetched coordinates for Sector 97: 28.4086° N, 76.8793° E
# Fetched coordinates for Sector 98: 28.4192° N, 76.8995° E
# Fetched coordinates for Sector 99: None
# Fetched coordinates for Sector 100: 28.4613° N, 76.9708° E
# Fetched coordinates for Sector 101: 28.4672° N, 76.9801° E
# Fetched coordinates for Sector 102: 28.4750° N, 76.9715° E
# Fetched coordinates for Sector 103: None
# Fetched coordinates for Sector 104: 28.4788° N, 76.9960° E
# Fetched coordinates for Sector 105: None
# Fetched coordinates for Sector 106: 28.5007° N, 77.0003° E
# Fetched coordinates for Sector 107: None
# Fetched coordinates for Sector 108: None
# Fetched coordinates for Sector 109: None
# Fetched coordinates for Sector 110: None
# Fetched coordinates for Sector 111: None
# Fetched coordinates for Sector 112: 28.5282° N, 77.0176° E
# Fetched coordinates for Sector 113: 28.5287° N, 77.0233° E
# Fetched coordinates for Sector 114: None
# Fetched coordinates for Sector 115: 28.5385° N, 77.0061° E
# Coordinates fetched and saved to gurgaon_sectors_coordinates1.csv
